# %% [markdown]
# # 04 - Model Validation
#
# Validación formal del modelo de regresión (user_score).

# %%
from pathlib import Path
import pandas as pd

project_dir = Path('..')
metrics_path = project_dir / 'reports' / 'prod' / 'performance_metrics.csv'
df = pd.read_csv(metrics_path)
df
# Out:
#                metric     value  rows_evaluated
# 0                 mae  0.452361              38
# 1                rmse  0.675948              38
# 2                  r2  0.585854              38
# 3     match_rate_date  0.000000              50
# 4       match_rate_id  1.000000              50
# 5  match_rate_missing  0.000000              50

# %%
# Resumen rapido
print(df.head(5))
# Out:
#             metric     value  rows_evaluated
# 0              mae  0.452361              38
# 1             rmse  0.675948              38
# 2               r2  0.585854              38
# 3  match_rate_date  0.000000              50
# 4    match_rate_id  1.000000              50
