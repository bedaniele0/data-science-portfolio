# %% [markdown]
# # 06 Dashboard Contract Review
#
# Revision ejecutable del contrato de datos consumido por el dashboard Streamlit.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
report = json.loads((ROOT / 'reports/dashboard_contract_report.json').read_text())
report

# %% [markdown]
# ## Dashboard checks

# %%
pd.Series(report["dashboard_checks"], name="passed").to_frame()

# %% [markdown]
# ## Snapshot de eventos

# %%
from src.dashboard.view_model import build_dashboard_snapshot, frame, kpi_summary

snapshot = build_dashboard_snapshot("configs/dashboard.yaml")
kpi_summary(snapshot)

# %%
events = frame(snapshot["events"])
events[["event_id", "event_title", "article_count", "media_count", "confidence", "status"]].head(8)

# %%
frame(snapshot["media_coverage"])[["media", "article_count", "event_count"]]
