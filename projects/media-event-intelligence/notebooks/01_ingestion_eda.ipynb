# %% [markdown]
# # 01 Ingestion EDA
#
# Explore the raw demo seed data and the normalized article contract produced by Component 1.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

pd.set_option("display.max_colwidth", 140)
ROOT

# %%
raw_path = ROOT / "data/raw/demo/google_news_sample_2026-02-16_2026-02-17.csv"
normalized_path = ROOT / "data/interim/normalized_articles.csv"
raw = pd.read_csv(raw_path, dtype=str, keep_default_na=False)
normalized = pd.read_csv(normalized_path, dtype=str, keep_default_na=False)
raw.shape, normalized.shape

# %%
raw.head()

# %%
normalized.head()

# %%
quality = {
    "raw_rows": len(raw),
    "normalized_rows": len(normalized),
    "removed_rows": len(raw) - len(normalized),
    "unique_media": normalized["media"].nunique(),
    "unique_queries": normalized["query"].nunique(),
    "date_min": normalized["published_at"].min(),
    "date_max": normalized["published_at"].max(),
}
quality

# %%
normalized["query"].value_counts().rename_axis("query").reset_index(name="articles")

# %%
normalized["media"].value_counts().head(20).rename_axis("media").reset_index(name="articles")
